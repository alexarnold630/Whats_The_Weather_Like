# %% [markdown]
# # Imports

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import seaborn as sns

#data science
import pandas as pd
import numpy as np

import requests
from pprint import pprint
import time


#regression
from scipy.stats import linregress
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities_new.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# # Generate City List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
cities_sub = cities[0: ]
cities_sub
# Out:
# ['punta arenas',
#  'bengkulu',
#  'severo-kurilsk',
#  'lillooet',
#  'tahoua',
#  'new norfolk',
#  'ushuaia',
#  'barra patuca',
#  'vardo',
#  'illoqqortoormiut',
#  'khatanga',
#  'puerto ayora',
#  'yellowknife',
#  'barrow',
#  'saleaula',
#  'can tho',
#  'kruisfontein',
#  'grafton',
#  'bolshaya sosnova',
#  'san carlos de bariloche',
#  'maumere',
#  'butaritari',
#  'avarua',
#  'sibolga',
#  'chokurdakh',
#  'cherskiy',
#  'hermanus',
#  'idrinskoye',
#  'kedgwick',
#  'albany',
#  'anadyr',
#  'fujin',
#  'cabinda',
#  'lensk',
#  'tonosho',
#  'atuona',
#  'campo largo',
#  'mahebourg',
#  'hamilton',
#  'xining',
#  'haines junction',
#  'rikitea',
#  'tomatlan',
#  'akoupe',
#  'port elizabeth',
#  'jamestown',
#  'karaul',
#  'escanaba',
#  'aklavik',
#  'eibergen',
#  'victoria',
#  'taolanaro',
#  'stokmarknes',
#  'mataura',
#  'havre de grace',
#  'ancud',
#  'bintulu',
#  'cabedelo',
#  'samarinda',
#  'busselton',
#  'quatre cocos',
#  'mahina',
#  'fevralsk',
#  'ise',
#  'mys shmidta',
#  'mukhen',
#  'wenling',
#  'guerrero negro',
#  'kurilsk',
#  'wanning',
#  'shahr-e kord',
#  'longyearbyen',
#  'norman wells',
#  'biloela',
#  'hobart',
#  'fort nelson',
#  'velingara',
#  'san patricio',
#  'el dorado',
#  'shahrud',
#  'lebu',
#  'humaita',
#  'vila velha',
#  'cabo san lucas',
#  'vaini',
#  'solnechnyy',
#  'dicabisagan',
#  'bluff',
#  'takoradi',
#  'faanui',
#  'hasaki',
#  'qaanaaq',
#  'kodiak',
#  'tsihombe',
#  'barentsburg',
#  'misratah',
#  'nicoya',
#  'rutana',
#  'kapaa',
#  'amderma',
#  'svetlaya',
#  'veshenskaya',
#  'grand river south east',
#  'aros',
#  'maceio',
#  'hilo',
#  'chumikan',
#  'nikolskoye',
#  'bargal',
#  'ternate',
#  'zykovo',
#  'walvis bay',
#  'castro',
#  'mutsamudu',
#  'sedelnikovo',
#  'ribeira grande',
#  'samagaltay',
#  'san cristobal',
#  'kahului',
#  'siwana',
#  'nioro',
#  'leningradskiy',
#  'ulladulla',
#  'marsa matruh',
#  'carnarvon',
#  'klaksvik',
#  'arraial do cabo',
#  'peniche',
#  'sioux lookout',
#  'turinskaya sloboda',
#  'saldanha',
#  'hovd',
#  'buala',
#  'cape town',
#  'saint george',
#  'upernavik',
#  'atambua',
#  'broken hill',
#  'kidal',
#  'el cairo',
#  'vao',
#  'latung',
#  'sal rei',
#  'tuatapere',
#  'parintins',
#  'roma',
#  'tarakan',
#  'san ramon',
#  'cidreira',
#  'kaitangata',
#  'sentyabrskiy',
#  'pitimbu',
#  'codrington',
#  'dipkarpaz',
#  'ewa beach',
#  'tuktoyaktuk',
#  'sovetskiy',
#  'sayyan',
#  'thompson',
#  'ponta do sol',
#  'santa rosa',
#  'hualmay',
#  'namatanai',
#  'kresttsy',
#  'port alfred',
#  'pareora',
#  'bambous virieux',
#  'x-can',
#  'vega de alatorre',
#  'belushya guba',
#  'tasiilaq',
#  'mount gambier',
#  'disna',
#  'hambantota',
#  'yate',
#  'chuy',
#  'yaan',
#  'souillac',
#  'gotsu',
#  'aborlan',
#  'esperance',
#  'palabuhanratu',
#  'tanete',
#  'mokhsogollokh',
#  'alofi',
#  'denpasar',
#  'ust-kuyga',
#  'faya',
#  'sao sebastiao',
#  'tiksi',
#  'solovetskiy',
#  'angoche',
#  'eyl',
#  'gondanglegi',
#  'hithadhoo',
#  'nouadhibou',
#  'sao filipe',
#  'praia',
#  'lavrentiya',
#  'clyde river',
#  'launceston',
#  'chernyshevskiy',
#  'castro verde',
#  'moose factory',
#  'isangel',
#  'cabatuan',
#  'noumea',
#  'todos santos',
#  'asau',
#  'lompoc',
#  'bredasdorp',
#  'buckeye',
#  'haimen',
#  'mongo',
#  'olafsvik',
#  'maiduguri',
#  'mar del plata',
#  'bambanglipuro',
#  'lata',
#  'barth',
#  'pimenta bueno',
#  'gilgit',
#  'bazarnyye mataki',
#  'dalianwan',
#  'richards bay',
#  'aykhal',
#  'rawannawi',
#  'flin flon',
#  'berbera',
#  'jodar',
#  'buncrana',
#  'benjamin constant',
#  'fairbanks',
#  'imeni poliny osipenko',
#  'nizhneyansk',
#  'constitucion',
#  'kavieng',
#  'gravdal',
#  'altamont',
#  'saskylakh',
#  'talnakh',
#  'luanda',
#  'carutapera',
#  'hofn',
#  'buluang',
#  'gat',
#  'fjerritslev',
#  'sao joao da barra',
#  'atar',
#  'beloha',
#  'east london',
#  'mujiayingzi',
#  'mayskiy',
#  'toguchin',
#  'kuytun',
#  'bubaque',
#  'koslan',
#  'attawapiskat',
#  'sibu',
#  'meulaboh',
#  'parry sound',
#  'jiazi',
#  'borba',
#  'seguin',
#  'tsiroanomandidy',
#  'pisco',
#  'dryden',
#  'khromtau',
#  'lagos',
#  'san vicente',
#  'nanortalik',
#  'wankaner',
#  'luderitz',
#  'livani',
#  'kavaratti',
#  'felidhoo',
#  'batagay',
#  'kloulklubed',
#  'bethel',
#  'broome',
#  'marzuq',
#  'rocky mountain house',
#  'hirna',
#  'kamenskoye',
#  'ramanathapuram',
#  'helong',
#  'pedernales',
#  'san policarpo',
#  'sur',
#  'saint-joseph',
#  'yafran',
#  'lagoa',
#  'grindavik',
#  'paita',
#  'tshikapa',
#  'koson',
#  'flinders',
#  'ngukurr',
#  'floro',
#  'jumla',
#  'merauke',
#  'maimon',
#  'iqaluit',
#  'nguiu',
#  'lolua',
#  'ketchikan',
#  'nome',
#  'nakhon thai',
#  'qui nhon',
#  'sorland',
#  'geraldton',
#  'pasighat',
#  'asfi',
#  'te anau',
#  'saint anthony',
#  'rio grande',
#  'deputatskiy',
#  'kushiro',
#  'yulara',
#  'avera',
#  'kennett',
#  'berezovyy',
#  'urucara',
#  'kupino',
#  'portland',
#  'camapua',
#  'vostok',
#  'gunjur',
#  'provideniya',
#  'pacific grove',
#  'rantepao',
#  'dikson',
#  'luxor',
#  'araouane',
#  'bang rakam',
#  'najran',
#  'gourcy',
#  'burla',
#  'bandar maharani',
#  'beira',
#  'namibe',
#  'sambava',
#  'novyy urengoy',
#  'waipawa',
#  'cayenne',
#  'makakilo city',
#  'kibuye',
#  'rayong',
#  'waingapu',
#  'koroni',
#  'aksha',
#  'sebeta',
#  'balikpapan',
#  'aranos',
#  'khani',
#  'bulgan',
#  'taoudenni',
#  'garowe',
#  'prince rupert',
#  'harper',
#  'ust-maya',
#  'urucurituba',
#  'port hedland',
#  'kuche',
#  'pionerskiy',
#  'dingle',
#  'eldikan',
#  'yumen',
#  'aswan',
#  'touros',
#  'slavyanka',
#  'krasnozatonskiy',
#  'colares',
#  'waldoboro',
#  'ziro',
#  'skjervoy',
#  'champerico',
#  'makurdi',
#  'puerto escondido',
#  'muros',
#  'zhigansk',
#  'dom pedro',
#  'zdvinsk',
#  'yinchuan',
#  'torbay',
#  'aba',
#  'snyder',
#  'san andres',
#  'hare bay',
#  'viedma',
#  'ostrovnoy',
#  'maniitsoq',
#  'khash',
#  'tumannyy',
#  'esqueda',
#  'necochea',
#  'bolshoye ignatovo',
#  'hanna',
#  'altay',
#  'bolshegrivskoye',
#  'hunza',
#  'palmer',
#  'ganzhou',
#  'carballo',
#  'mayo',
#  'mount isa',
#  'dedza',
#  'tarudant',
#  'wamba',
#  'santa clara',
#  'ust-bolsheretsk',
#  'rechitsy',
#  'kasongo-lunda',
#  'okhotsk',
#  'liverpool',
#  'bongaree',
#  'tat',
#  'oranjemund',
#  'coruripe',
#  'novo aripuana',
#  'rundu',
#  'chagda',
#  'taloqan',
#  'uarini',
#  'salalah',
#  'mims',
#  'kedrovyy',
#  'dali',
#  'grand gaube',
#  'ilulissat',
#  'hervey bay',
#  'talcahuano',
#  'artyk',
#  'karkaralinsk',
#  'karlskrona',
#  'gibraleon',
#  'dijkot',
#  'road town',
#  'coihaique',
#  'taltal',
#  'usinsk',
#  'oktyabrskiy',
#  'ngunguru',
#  'nalut',
#  'hay river',
#  'port lincoln',
#  'ghansor',
#  'esna',
#  'bandikui',
#  'dawei',
#  'xingyi',
#  'pyshma',
#  'nishihara',
#  'naqadeh',
#  'alta floresta',
#  'oliveira dos brejinhos',
#  'buerarema',
#  'passa quatro',
#  'miraflores',
#  'port macquarie',
#  'chara',
#  'kencong',
#  'inuvik',
#  'lorengau',
#  'puerto quijarro',
#  'senahu',
#  'sundargarh',
#  'del rio',
#  'rungata',
#  'rengo',
#  'pochutla',
#  'marsh harbour',
#  'camacha',
#  'fortuna',
#  'arlit',
#  'moldava nad bodvou',
#  'valjala',
#  'kushima',
#  'wladyslawowo',
#  'ajdabiya',
#  'turbo',
#  'virginia',
#  'ahipara',
#  'cacoal',
#  'zhoucheng',
#  'sitka',
#  'georgetown',
#  'udachnyy',
#  'shiojiri',
#  'coffs harbour',
#  'brandon',
#  'sangar',
#  'paralimni',
#  'forbes',
#  'mahanoro',
#  'paamiut',
#  'lethem',
#  'comodoro rivadavia',
#  'bako',
#  'samusu',
#  'caravelas',
#  'ocnele mari',
#  'arnedo',
#  'addi ugri',
#  'balkhash',
#  'strathmore',
#  'ginda',
#  'yarim',
#  'westport',
#  'tokuyama',
#  'kardymovo',
#  'ruatoria',
#  'pevek',
#  'guilin',
#  'suluktu',
#  'yerbogachen',
#  'viligili',
#  'adrar',
#  'zhanatas',
#  'bethanien',
#  'virginia beach',
#  'rafaela',
#  'gorontalo',
#  'yar-sale',
#  'kappeln',
#  'doka',
#  'tanout',
#  'beisfjord',
#  'port keats',
#  'mizdah',
#  'buena vista',
#  'tura',
#  'hays',
#  'alice springs',
#  'saint-philippe',
#  'baculin',
#  'bafoulabe',
#  'port hardy',
#  'umzimvubu',
#  'thanh hoa',
#  'airai',
#  'vila franca do campo',
#  'belaya gora',
#  'kaka',
#  'puri',
#  'emerald',
#  'cockburn harbour',
#  'yamada',
#  'tautira',
#  'zhaodong',
#  'tambul',
#  'gualeguaychu',
#  'fukue',
#  'bara',
#  'katsuura',
#  'si sa ket',
#  'arman',
#  'ridgecrest',
#  'albanel',
#  'morgan city',
#  'labuhan',
#  'kirakira',
#  'awjilah',
#  'mbandaka',
#  'coquimbo',
#  'yashan',
#  'san joaquin',
#  'palana',
#  'muzhi',
#  'nabire',
#  'guantanamo',
#  'la ronge',
#  'kenora',
#  'mentougou',
#  'ceyranbatan',
#  'north bend',
#  'amga',
#  'berlevag',
#  'suruc',
#  'chapais',
#  'gainesville',
#  'naze',
#  'bonavista',
#  'ullapool',
#  'victoria point',
#  'ardistan',
#  'qurayyat',
#  'boromo',
#  'san felipe',
#  'marquard',
#  'machaneng',
#  'chontalpa',
#  'byron bay',
#  'mugla',
#  'torata',
#  'kulhudhuffushi',
#  'mana',
#  'neopolis',
#  'amapa',
#  'ritchie',
#  'olga',
#  'sawakin',
#  'okha',
#  'macheng',
#  'bumba',
#  'marondera',
#  'kegayli',
#  'sosnovo-ozerskoye',
#  'koumac',
#  'nyimba',
#  'sao felix do xingu',
#  'havre-saint-pierre',
#  'abu kamal',
#  'hagere selam',
#  'plettenberg bay',
#  'kamenka',
#  'verkh-usugli',
#  'mogadishu',
#  'dolores',
#  'tuy hoa',
#  'bud',
#  'auki',
#  'kieta',
#  'knysna',
#  'cururupu',
#  'dzaoudzi',
#  'da-an',
#  'hue']

# %% [markdown]
# # Make Requests

# %%
cities = []

#init lists to hold parsed data
lats =[]
longs =[]
temps = []
humids = []
clouds = []
speeds = []
city_names = []

for i in range(len(cities_sub)):
    city = cities_sub[i]
    
    #create the url
    units = "imperial"
    url = f"http://api.openweathermap.org/data/2.5/weather?q={city}&units={units}&appid={weather_api_key}"
    #print(url)
    
    #make the request
    response = requests.get(url)
    #print(response.status_code)
    
    #error check
    if response.status_code == 200:
        data = response.json()
        #pprint(data)
    
        try:
            #extract the data
            lat =data["coord"]["lat"]
            long = data["coord"]["lon"]
            temp = data["main"]["temp"]
            humidity = data["main"]["humidity"]
            cloudiness = data["clouds"]["all"]
            speed = data["wind"]["speed"]
            city_name = data["name"]

            #save the data
            city_names.append(city_name)
            lats.append(lat)
            longs.append(long)
            temps.append(temp)
            humids.append(humidity)
            clouds.append(cloudiness)
            speeds.append(speed)

        except Exception as e:
            print(f"Through exception for city {city}: {e}")
    
    elif response.status_code == 404:
        print (f"Missing data in OpenWeatherAPI for {city}")
        
    else:
        print(response.status_code)
        print("Oh gosh darnit. The API is broken. Sad Face.")
    
    #print every 5
    if (i % 5 ==0):
        print (f"Got data for city index: {i} of {len(cities_sub)}")
        
    time.sleep(1)
    
# make the dataframe
df = pd.DataFrame()
df["City Name"] = city_names
df["Latitude"] = lats
df["Longitude"] = longs
df["Temperature"] = temps
df["Humidity"] = humids
df["Cloudiness"] = clouds
df["Wind Speed"] = speeds
df.head(10)
# Out:
# Got data for city index: 0 of 628
# Got data for city index: 5 of 628
# Missing data in OpenWeatherAPI for illoqqortoormiut
# Got data for city index: 10 of 628
# Missing data in OpenWeatherAPI for saleaula
# Got data for city index: 15 of 628
# Got data for city index: 20 of 628
# Got data for city index: 25 of 628
# Got data for city index: 30 of 628
# Got data for city index: 35 of 628
# Got data for city index: 40 of 628
# Got data for city index: 45 of 628
# Missing data in OpenWeatherAPI for karaul
# Got data for city index: 50 of 628
# Missing data in OpenWeatherAPI for taolanaro
# Got data for city index: 55 of 628
# Got data for city index: 60 of 628
# Missing data in OpenWeatherAPI for fevralsk
# Missing data in OpenWeatherAPI for mys shmidta
# Got data for city index: 65 of 628
# Got data for city index: 70 of 628
# Got data for city index: 75 of 628
# Got data for city index: 80 of 628
# Got data for city index: 85 of 628
# Got data for city index: 90 of 628
# Missing data in OpenWeatherAPI for tsihombe
# Missing data in OpenWeatherAPI for barentsburg
# Got data for city index: 95 of 628
# Missing data in OpenWeatherAPI for amderma
# Got data for city index: 100 of 628
# Missing data in OpenWeatherAPI for grand river south east
# Got data for city index: 105 of 628
# Missing data in OpenWeatherAPI for bargal
# Got data for city index: 110 of 628
# Missing data in OpenWeatherAPI for mutsamudu
# Missing data in OpenWeatherAPI for sedelnikovo
# Got data for city index: 115 of 628
# Got data for city index: 120 of 628
# Got data for city index: 125 of 628
# Got data for city index: 130 of 628
# Got data for city index: 135 of 628
# Got data for city index: 140 of 628
# Got data for city index: 145 of 628
# Missing data in OpenWeatherAPI for sentyabrskiy
# Got data for city index: 150 of 628
# Missing data in OpenWeatherAPI for dipkarpaz
# Got data for city index: 155 of 628
# Got data for city index: 160 of 628
# Got data for city index: 165 of 628
# Missing data in OpenWeatherAPI for x-can
# Missing data in OpenWeatherAPI for belushya guba
# Got data for city index: 170 of 628
# Got data for city index: 175 of 628
# Got data for city index: 180 of 628
# Missing data in OpenWeatherAPI for palabuhanratu
# Got data for city index: 185 of 628
# Missing data in OpenWeatherAPI for solovetskiy
# Got data for city index: 190 of 628
# Got data for city index: 195 of 628
# Got data for city index: 200 of 628
# Got data for city index: 205 of 628
# Got data for city index: 210 of 628
# Got data for city index: 215 of 628
# Got data for city index: 220 of 628
# Got data for city index: 225 of 628
# Missing data in OpenWeatherAPI for rawannawi
# Got data for city index: 230 of 628
# Missing data in OpenWeatherAPI for nizhneyansk
# Got data for city index: 235 of 628
# Got data for city index: 240 of 628
# Got data for city index: 245 of 628
# Got data for city index: 250 of 628
# Got data for city index: 255 of 628
# Missing data in OpenWeatherAPI for attawapiskat
# Got data for city index: 260 of 628
# Got data for city index: 265 of 628
# Got data for city index: 270 of 628
# Missing data in OpenWeatherAPI for felidhoo
# Got data for city index: 275 of 628
# Got data for city index: 280 of 628
# Missing data in OpenWeatherAPI for kamenskoye
# Got data for city index: 285 of 628
# Got data for city index: 290 of 628
# Got data for city index: 295 of 628
# Missing data in OpenWeatherAPI for ngukurr
# Got data for city index: 300 of 628
# Missing data in OpenWeatherAPI for maimon
# Missing data in OpenWeatherAPI for nguiu
# Missing data in OpenWeatherAPI for lolua
# Got data for city index: 305 of 628
# Got data for city index: 310 of 628
# Got data for city index: 315 of 628
# Got data for city index: 320 of 628
# Got data for city index: 325 of 628
# Got data for city index: 330 of 628
# Got data for city index: 335 of 628
# Missing data in OpenWeatherAPI for bandar maharani
# Got data for city index: 340 of 628
# Got data for city index: 345 of 628
# Got data for city index: 350 of 628
# Got data for city index: 355 of 628
# Got data for city index: 360 of 628
# Missing data in OpenWeatherAPI for kuche
# Got data for city index: 365 of 628
# Missing data in OpenWeatherAPI for eldikan
# Got data for city index: 370 of 628
# Got data for city index: 375 of 628
# Got data for city index: 380 of 628
# Got data for city index: 385 of 628
# Got data for city index: 390 of 628
# Missing data in OpenWeatherAPI for tumannyy
# Got data for city index: 395 of 628
# Missing data in OpenWeatherAPI for bolshoye ignatovo
# Missing data in OpenWeatherAPI for bolshegrivskoye
# Missing data in OpenWeatherAPI for hunza
# Got data for city index: 400 of 628
# Got data for city index: 405 of 628
# Missing data in OpenWeatherAPI for tarudant
# Missing data in OpenWeatherAPI for ust-bolsheretsk
# Got data for city index: 410 of 628
# Got data for city index: 415 of 628
# Got data for city index: 420 of 628
# Missing data in OpenWeatherAPI for chagda
# Got data for city index: 425 of 628
# Got data for city index: 430 of 628
# Missing data in OpenWeatherAPI for artyk
# Missing data in OpenWeatherAPI for karkaralinsk
# Got data for city index: 435 of 628
# Got data for city index: 440 of 628
# Got data for city index: 445 of 628
# Got data for city index: 450 of 628
# Got data for city index: 455 of 628
# Got data for city index: 460 of 628
# Got data for city index: 465 of 628
# Missing data in OpenWeatherAPI for rungata
# Got data for city index: 470 of 628
# Got data for city index: 475 of 628
# Missing data in OpenWeatherAPI for valjala
# Got data for city index: 480 of 628
# Got data for city index: 485 of 628
# Got data for city index: 490 of 628
# Got data for city index: 495 of 628
# Missing data in OpenWeatherAPI for samusu
# Got data for city index: 500 of 628
# Missing data in OpenWeatherAPI for addi ugri
# Got data for city index: 505 of 628
# Got data for city index: 510 of 628
# Missing data in OpenWeatherAPI for ruatoria
# Got data for city index: 515 of 628
# Missing data in OpenWeatherAPI for viligili
# Missing data in OpenWeatherAPI for zhanatas
# Got data for city index: 520 of 628
# Got data for city index: 525 of 628
# Got data for city index: 530 of 628
# Got data for city index: 535 of 628
# Missing data in OpenWeatherAPI for umzimvubu
# Got data for city index: 540 of 628
# Got data for city index: 545 of 628
# Missing data in OpenWeatherAPI for cockburn harbour
# Missing data in OpenWeatherAPI for tambul
# Got data for city index: 550 of 628
# Got data for city index: 555 of 628
# Got data for city index: 560 of 628
# Got data for city index: 565 of 628
# Got data for city index: 570 of 628
# Got data for city index: 575 of 628
# Got data for city index: 580 of 628
# Missing data in OpenWeatherAPI for ardistan
# Got data for city index: 585 of 628
# Got data for city index: 590 of 628
# Got data for city index: 595 of 628
# Got data for city index: 600 of 628
# Got data for city index: 605 of 628
# Missing data in OpenWeatherAPI for kegayli
# Got data for city index: 610 of 628
# Got data for city index: 615 of 628
# Got data for city index: 620 of 628
# Got data for city index: 625 of 628
# Missing data in OpenWeatherAPI for da-an
#          City Name  Latitude  Longitude  Temperature  Humidity  Cloudiness  \
# 0     Punta Arenas    -53.15     -70.92        46.40        81          90
# 1         Bengkulu     -3.80     102.27        75.29        86         100
# 2  Severo-Kuril'sk     50.68     156.12        38.79        73          98
# 3         Lillooet     50.69    -121.94        50.85        93          90
# 4           Tahoua     14.89       5.27        82.40        23           0
# 5      New Norfolk    -42.78     147.06        46.83        63           1
# 6          Ushuaia    -54.80     -68.30        66.20        37           0
# 7     Barra Patuca     15.80     -84.28        77.72        91         100
# 8            Vardø     70.37      31.11        39.20        80          75
# 9         Khatanga     71.97     102.50        -6.59        90          13
#
#    Wind Speed
# 0        8.05
# 1        4.03
# 2       31.65
# 3        8.05
# 4        4.70
# 5        1.01
# 6        3.36
# 7       13.42
# 8       28.86
# 9        8.10

# %%
df.to_csv(output_data_file, index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0465120141ef> in <module>
# ----> 1 df.to_csv(output_data_file, index=False)
#
# NameError: name 'df' is not defined
